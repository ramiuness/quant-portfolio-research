# %%
import polars as pl 
import pandas as pd
import numpy as np
import requests

# %% [markdown]
# ## Fetch SP500 companies meta data

# %%
# Collect the SP500 from the Wikipedia page
url = "https://en.wikipedia.org/wiki/List_of_S%26P_500_companies"

headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'} # Mimic a browser to avoid 403 Error
tables = pd.read_html(url, storage_options={'User-Agent': headers['User-Agent']})
sp_meta1 = tables[0]
sp_meta2 = tables[1]
sp_meta2.columns = sp_meta2.columns.map('_'.join)
sp500 = set(sp_meta1.Symbol).difference(set(sp_meta2.Removed_Ticker)).union(set(sp_meta2.Added_Ticker))
sp_meta1.rename(columns={'Symbol':'tic', 'GICS Sector':'gics_sector', 'GICS Sub-Industry':'gics_sub_industy',
                         'Headquarters Location':'hq_loc', 'Founded':'founded_date'}, inplace=True)
 

sp_meta1.drop(['Security', 'Date added', 'CIK'], axis=1, inplace=True)
sp_meta1['founded_date'] = sp_meta1["founded_date"].str.findall(r"\b\d{4}\b").apply(lambda x: min(map(int, x)) if x else None)
sp_meta1['hq_loc'] = sp_meta1['hq_loc'].str.split(',').apply(lambda x: x[-1])
sp_meta = sp_meta1
del sp_meta1, sp_meta2

# %% [markdown]
# ## Define the investment universe data

# %%
data_dir = '~/Documents/folio/gill-hack/2025/ASSET MANAGEMENT HACKATHON 2025/data/'
data = pd.read_csv(data_dir + 'modeling_data.csv')
cmpny_us = (data[data.fic == 'USA'][
             ['gvkey','iid','tic', 'conm', 'market_equity']]
                .drop_duplicates(subset=['gvkey','iid','tic', 'conm'])
                .dropna()
                .sort_values(by='market_equity', ascending=False)
                .reset_index(drop=True)
           )



# Consolidate with the meta data
cmpny_us = cmpny_us.merge(sp_meta, how='left', on=['tic'])

# %%
# Filter the available US stocks with a market equity above .25 quantile criterion
invst_univ = cmpny_us[cmpny_us['market_equity']>=cmpny_us['market_equity'].quantile(0.25)]

# %%
invst_univ_data = data[
                        data['gvkey'].isin(invst_univ['gvkey']) & data['iid'].isin(invst_univ['iid'])
                  ].drop(['tpci', 'fic'], axis=1)

# %%
invst_univ_data.tic.nunique()

# %%
invst_univ_data.info()

# %%
pl.from_pandas(invst_univ_data).write_csv('../data/invst_univ_data.csv')

# %% [markdown]
# ## Consolidate with SP500 meta data

# %%
keys = set(invst_univ_data.columns).intersection(set(cmpny_us.columns))
invst_univ_data = invst_univ_data.merge(cmpny_us, how='left', on=list(keys))
invst_univ_data = invest_univ_data.loc[:, ['gvkey', 'iid', 'id', 'date', 'tic', 'conm', 'market_equity', 'gics_sector', 'gics_sub_industy',
       'hq_loc', 'founded_date', 'year', 'month','dolvol_126d', 'turnover_126d', 'ivol_ff3_21d', 'ni_ivol', 'beta_60m',
       'z_score', 'f_score', 'netdebt_me', 'rd_sale', 'ebit_bev', 'ebit_sale',
       'ni_be', 'niq_be', 'ocf_at', 'gp_at', 'niq_at', 'op_at', 'rd_me',
       'be_me', 'div12m_me', 'ni_me', 'sale_me', 'rf_feature', 'mgmt_feature',
       'target_ret']]

# %%
pl.from_pandas( invst_univ_data).write_csv('../data/invst_univ_data.csv')

# %% [markdown]
# ## Consolidate with SIC dummies

# %%
# Read the data fecthed using the feth from edgar pipelin
sic_dummies_lnktabl = pd.read_csv('../data/invst_univ_companies_with_sic.csv')
sic_dummies_lnktabl.head()
# Out:
#     tic                     conm     SIC                          SIC_desc  \
# 0   XOM         EXXON MOBIL CORP  2911.0                Petroleum Refining
# 1  CHFC  CHEMICAL FINANCIAL CORP     NaN                               NaN
# 2    GR            GOODRICH CORP     NaN                               NaN
# 3   PEP              PEPSICO INC  2080.0                         Beverages
# 4   TXN    TEXAS INSTRUMENTS INC  3674.0  Semiconductors & Related Devices
#
#    SIC2
# 0  29.0
# 1   NaN
# 2   NaN
# 3  20.0
# 4  36.0

# %%
sic_dummies_lnktabl = sic_dummies_lnktabl.merge(invst_univ_data[['conm', 'tic', 'gvkey', 'iid']], 
                                                on=['conm', 'tic'], 
                                                how='left', 
                                                validate='one_to_many').drop_duplicates().dropna()

sic_dummies_lnktabl = sic_dummies_lnktabl.astype({'SIC2': int, 'SIC': int})

# %%
sic_dummies_lnktabl
# Out:
#        tic                         conm   SIC  \
# 0      XOM             EXXON MOBIL CORP  2911
# 11     PEP                  PEPSICO INC  2080
# 12     TXN        TEXAS INSTRUMENTS INC  3674
# 23     BOH          BANK OF HAWAII CORP  6022
# 31      BA                    BOEING CO  3721
# ...    ...                          ...   ...
# 9696  VLTO                 VERALTO CORP  3825
# 9697  LINE                  LINEAGE INC  6798
# 9698   PMT  PENNYMAC MORTGAGE INVEST TR  6798
# 9699   INN  SUMMIT HOTEL PROPERTIES INC  6798
# 9700   KRG      KITE REALTY GROUP TRUST  6798
#
#                                                SIC_desc  SIC2   gvkey iid
# 0                                    Petroleum Refining    29    4503  01
# 11                                            Beverages    20    8479  01
# 12                     Semiconductors & Related Devices    36   10499  01
# 23                               State Commercial Banks    60    2005  01
# 31                                             Aircraft    37    2285  01
# ...                                                 ...   ...     ...  ..
# 9696  Instruments For Meas & Testing of  Electricity...    38   43197  01
# 9697                      Real Estate Investment Trusts    67   50389  01
# 9698                      Real Estate Investment Trusts    67  183324  01
# 9699                      Real Estate Investment Trusts    67  185396  01
# 9700                      Real Estate Investment Trusts    67  266315  01
#
# [2000 rows x 7 columns]

# %%
# 
cols = ['tic', 'conm']

for col in cols:
    filled = (
    invst_univ_data
      .groupby(['gvkey','iid'])[col]
      .transform(lambda s: s.ffill().bfill())
)
    invst_univ_data[col] = filled.infer_objects(copy=False).astype('string')

invst_univ_data = invst_univ_data.merge(sic_dummies_lnktabl, on=['conm', 'tic', 'gvkey', 'iid'], how='left', validate='many_to_one').drop_duplicates().dropna(subset=['SIC2'])

# %%
invst_univ_data.dropna(subset=['SIC2'])
# Out:
#          gvkey iid              id      date   tic  \
# 1         9728  02  comp_009728_02  20050228   MUX
# 2        13071  01  comp_013071_01  20050228  RDNT
# 3        15240  02  comp_015240_02  20050228   WWR
# 4        17602  01  comp_017602_01  20050228  BHRB
# 5        17877  01  comp_017877_01  20050228  CHMG
# ...        ...  ..             ...       ...   ...
# 515561  315318  01  comp_315318_01  20250630   ESI
# 515562  316056  01  comp_316056_01  20250630  ALLE
# 515563  317264  01  comp_317264_01  20250630   LPG
# 515564  326688  01  comp_326688_01  20250630   NVT
# 515565  328795  01  comp_328795_01  20250630   ACA
#
#                                 conm  market_equity   dolvol_126d  \
# 1                         MCEWEN INC       7.569090  1.479429e+04
# 2                         RADNET INC      19.320290  3.125634e+04
# 3            WESTWATER RESOURCES INC     112.778970  3.941216e+05
# 4       BURKE HERBERT FINL SRVS CORP            NaN  4.156433e+04
# 5             CHEMUNG FINANCIAL CORP     115.602175  6.325633e+04
# ...                              ...            ...           ...
# 515561         ELEMENT SOLUTIONS INC    5184.735520  5.925649e+07
# 515562                  ALLEGION PLC   12279.192300  1.264881e+08
# 515563                DORIAN LPG LTD     913.093680  1.790935e+07
# 515564            NVENT ELECTRIC PLC   10833.048800  1.308619e+08
# 515565                    ARCOSA INC    4211.356320  2.519535e+07
#
#         turnover_126d  ivol_ff3_21d  ...     ni_me   sale_me  rf_feature  \
# 1            0.001550      0.026080  ... -0.101333  0.000000         NaN
# 2            0.001401      0.046515  ... -0.407965  7.162004         NaN
# 3            0.004194      0.030881  ... -0.129590  0.000000         NaN
# 4                 NaN      0.004553  ...       NaN       NaN         NaN
# 5            0.000557      0.009080  ...       NaN       NaN         NaN
# ...               ...           ...  ...       ...       ...         ...
# 515561       0.010482           NaN  ...  0.046791  0.473872         NaN
# 515562       0.011089           NaN  ...  0.048660  0.307203         NaN
# 515563       0.018638           NaN  ...  0.176673  0.016281         NaN
# 515564       0.012945           NaN  ...  0.022228  0.277493         NaN
# 515565       0.005832           NaN  ...  0.022249  0.610231         NaN
#
#         mgmt_feature  target_ret  year  month     SIC  \
# 1                NaN    0.027027  2005      2  1040.0
# 2                NaN   -0.212766  2005      2  8071.0
# 3                NaN    0.017241  2005      2  1000.0
# 4                NaN    0.000000  2005      2  6021.0
# 5                NaN    0.022998  2005      2  6022.0
# ...              ...         ...   ...    ...     ...
# 515561           NaN    0.063407  2025      6  2890.0
# 515562           NaN    0.013758  2025      6  7381.0
# 515563           NaN    0.138720  2025      6  4412.0
# 515564           NaN    0.113222  2025      6  3550.0
# 515565           NaN    0.005100  2025      6  3440.0
#
#                                                  SIC_desc  SIC2
# 1                                    Gold and Silver Ores  10.0
# 2                           Services-Medical Laboratories  80.0
# 3                                            Metal Mining  10.0
# 4                               National Commercial Banks  60.0
# 5                                  State Commercial Banks  60.0
# ...                                                   ...   ...
# 515561                    Miscellaneous Chemical Products  28.0
# 515562   Services-Detective, Guard & Armored Car Services  73.0
# 515563        Deep Sea Foreign Transportation of  Freight  44.0
# 515564  Special Industry Machinery (No Metalworking Ma...  35.0
# 515565               Fabricated Structural Metal Products  34.0
#
# [359250 rows x 37 columns]

# %%
pl.from_pandas(invst_univ_data).write_csv('../data/invst_univ_data_with_sic.csv')

# %% [markdown]
# ## Explore the source of NAs

# %%
invst_univ_data.drop(['rf_feature', 'mgmt_feature'], axis=1).dropna()
# Out:
#           gvkey iid          id      date     tic                        conm  \
# 17343     11903  01  crsp_10025  20050228    AEPI          AEP INDUSTRIES INC
# 17357     12141  01  crsp_10107  20050228    MSFT              MICROSOFT CORP
# 17364     12053  01  crsp_10147  20050228   EMC.2                 EMC CORP/MA
# 17368     12181  01  crsp_10200  20050228    RGEN               REPLIGEN CORP
# 17371      1408  01  crsp_10225  20050228  BEAM.2                    BEAM INC
# ...         ...  ..         ...       ...     ...                         ...
# 6236404  179841  01  crsp_93345  20241231    CDXS                 CODEXIS INC
# 6236407  183974  01  crsp_93356  20241231    SPSC            SPS COMMERCE INC
# 6236410  184258  01  crsp_93372  20241231    PLOW        DOUGLAS DYNAMICS INC
# 6236413  185138  01  crsp_93426  20241231     VPG  VISHAY PRECISION GROUP INC
# 6236416  184996  01  crsp_93436  20241231    TSLA                   TESLA INC
#
#          market_equity   dolvol_126d  turnover_126d  ivol_ff3_21d  ...  \
# 17343     1.590375e+02  3.598615e+05       0.002923      0.039046  ...
# 17357     2.859322e+05  5.725156e+08       0.006475      0.005927  ...
# 17364     3.139126e+04  1.631799e+08       0.005432      0.013269  ...
# 17368     6.917020e+01  3.639339e+05       0.005309      0.041756  ...
# 17371     1.210597e+04  4.059626e+07       0.003729      0.014250  ...
# ...                ...           ...            ...           ...  ...
# 6236404   3.727112e+02  1.772361e+06       0.007160      0.040815  ...
# 6236407   7.253254e+03  3.664191e+07       0.005164      0.009399  ...
# 6236410   5.979036e+02  4.998834e+06       0.008427      0.007979  ...
# 6236413   2.806015e+02  2.024922e+06       0.006262      0.020405  ...
# 6236416   1.107984e+06  1.785044e+09       0.028598      0.039697  ...
#
#            niq_at     op_at     rd_me     be_me  div12m_me     ni_me  \
# 17343   -0.003451  0.118364  0.011318  0.277796   0.000000 -0.108911
# 17357    0.027363  0.224901  0.026922  0.265608   0.120160  0.028265
# 17364    0.015048  0.162282  0.027338  0.358809   0.000000  0.024553
# 17368   -0.059221  0.038262  0.084097  0.359664   0.000000 -0.111999
# 17371    0.024446  0.164309  0.004799  0.237437   0.015079  0.053750
# ...           ...       ...       ...       ...        ...       ...
# 6236404 -0.152147 -0.003720  0.127595  0.164865   0.000000 -0.204877
# 6236407  0.021471  0.206998  0.008017  0.097947   0.000000  0.009911
# 6236410  0.042175  0.123704  0.016861  0.442073   0.045469  0.048260
# 6236413  0.009873  0.110314  0.072701  1.177898   0.000000  0.074843
# 6236416  0.012817  0.147981  0.004043  0.059990   0.000000  0.011346
#
#           sale_me  target_ret  year  month
# 17343    4.060459    0.082228  2005      2
# 17357    0.132231   -0.039574  2005      2
# 17364    0.246381   -0.033588  2005      2
# 17368    0.109006   -0.213043  2005      2
# 17371    0.489568   -0.031555  2005      2
# ...           ...         ...   ...    ...
# 6236404  0.163370    0.041485  2024     12
# 6236407  0.080488   -0.047030  2024     12
# 6236410  0.959892   -0.075898  2024     12
# 6236413  1.188604    0.021768  2024     12
# 6236416  0.086028    0.170008  2024     12
#
# [199112 rows x 32 columns]

# %%
most_na = ['SIC',
 'SIC2',
 'SIC_desc',
 'conm',
 'mgmt_feature', # reviuse if links with (gvkey, iid) would yield less NAs
 'rd_me', # just drop it
 'rd_sale', # just drop it
 'rf_feature',
 'tic']

(invst_univ_data.merge(sic_dummies_lnktabl, on=['conm', 'tic', 'gvkey', 'iid'], how='left')
    .loc[:, 
                  ['gvkey', 'iid', 'date', 'tic', 'conm', 'market_equity',
                    'SIC', 'SIC_desc', 'SIC2', 'year',
                    'month', 'dolvol_126d', 'turnover_126d', 'ivol_ff3_21d', 'ni_ivol',
                    'beta_60m', 'z_score', 'f_score', 'netdebt_me', 'rd_sale', 'ebit_bev',
                    'ebit_sale', 'ni_be', 'niq_be', 'ocf_at', 'gp_at', 'niq_at', 'op_at',
                    'rd_me', 'be_me', 'div12m_me', 'ni_me', 'sale_me', 'rf_feature',
                    'mgmt_feature', 'target_ret']]
    
).drop_duplicates().dropna()
# Out:
#          gvkey iid      date   tic                          conm  \
# 127       4503  01  20050228   XOM              EXXON MOBIL CORP
# 184      10499  01  20050228   TXN         TEXAS INSTRUMENTS INC
# 221       2285  01  20050228    BA                     BOEING CO
# 238       6774  01  20050228   LMT          LOCKHEED MARTIN CORP
# 245       8530  01  20050228   PFE                    PFIZER INC
# ...        ...  ..       ...   ...                           ...
# 504805   24844  03  20241031  SPOK             SPOK HOLDINGS INC
# 504963  174236  01  20241031   SEM  SELECT MEDICAL HOLDINGS CORP
# 504968  183366  01  20241031     H             HYATT HOTELS CORP
# 504971   12785  01  20241031   PPC          PILGRIM'S PRIDE CORP
# 504981  179841  01  20241031  CDXS                   CODEXIS INC
#
#         market_equity     SIC                                  SIC_desc  SIC2  \
# 127     332886.863760  2911.0                        Petroleum Refining  29.0
# 184      40105.137668  3674.0          Semiconductors & Related Devices  36.0
# 221      42483.606919  3721.0                                  Aircraft  37.0
# 238      25591.100168  3760.0  Guided Missiles & Space Vehicles & Parts  37.0
# 245     181948.838050  2834.0               Pharmaceutical Preparations  28.0
# ...               ...     ...                                       ...   ...
# 504805     305.175848  4812.0             Radiotelephone Communications  48.0
# 504963    4533.832131  8060.0                        Services-Hospitals  80.0
# 504968    6838.193663  7011.0                           Hotels & Motels  70.0
# 504971   10919.467919  2015.0       Poultry Slaughtering and Processing  20.0
# 504981     250.638074  2860.0              Industrial Organic Chemicals  28.0
#
#         year  ...    niq_at     op_at     rd_me     be_me  div12m_me  \
# 127     2005  ...  0.031383  0.211692  0.001856  0.345754   0.020746
# 184     2005  ...  0.035078  0.350809  0.048348  0.323126   0.003991
# 221     2005  ...  0.008069  0.105456  0.044817  0.224604   0.015076
# 238     2005  ...  0.011700  0.102462  0.035286  0.282911   0.015853
# 245     2005  ...  0.027492  0.225675  0.047964  0.440481   0.028351
# ...      ...  ...       ...       ...       ...       ...        ...
# 504805  2024  ...  0.018605  0.175467  0.036068  0.524842   0.082666
# 504963  2024  ...  0.005538  0.090353  0.000000  0.331126   0.014244
# 504968  2024  ...  0.040676  0.060159  0.000000  0.541810   0.003921
# 504971  2024  ...  0.017779  0.125684  0.000522  0.355481   0.000000
# 504981  2024  ... -0.084248  0.104868  0.213359  0.316261   0.000000
#
#            ni_me   sale_me  rf_feature  mgmt_feature  target_ret
# 127     0.070775  0.738599    0.000000      0.000038    0.232171
# 184     0.046977  0.304126    0.000000      0.000034    0.140457
# 221     0.064990  1.231040    0.000000      0.018250    0.091304
# 238     0.048376  1.349649    0.000000      0.009066    0.028715
# 245     0.049866  0.283459    0.000000      0.000030    0.096027
# ...          ...       ...         ...           ...         ...
# 504805  0.055001  0.461223    0.026945      0.003403    0.033864
# 504963  0.047480  1.394028    0.000211      0.007393   -0.080011
# 504968  0.100026  0.979937    0.000165      0.002930   -0.044350
# 504971  0.044948  1.608002    0.000474      0.003991    0.051900
# 504981 -0.259849  0.296180    0.134481      0.003415    0.019481
#
# [2622 rows x 36 columns]

# %%
invst_univ_data.groupby(['gvkey', 'iid']).size()
# Out:
# gvkey   iid
# 1004    01     244
# 1034    01      46
# 1045    01      83
#         04     137
# 1050    01     244
#               ...
# 326688  01      84
# 328795  01      78
# 333070  01      15
# 339965  01      51
# 343180  01      41
# Length: 3409, dtype: int64

# %%
# Collect the number of data points per security
df = (invst_univ_data
           .groupby(['gvkey','iid'])
           .agg(n_tic=('tic','size'), # size() counts NAs included, count() only NAs
                n_unique=('tic','nunique'),
                tic=('tic','first'),
                conm=('conm', 'first'),
                min_date=('date','min'),
                max_date=('date','max'))
           .sort_values('n_tic', ascending=False)
           .reset_index()
     )

# %%
df.dropna()
# Out:
#        gvkey iid  n_tic  n_unique   tic                          conm  \
# 0     157307  01    245         1  ISBA            ISABELLA BANK CORP
# 1     153616  01    245         1  EFSI  EAGLE FINANCIAL SERVICES INC
# 2       1004  01    244         1   AIR                      AAR CORP
# 3      63456  01    244         1   CSV         CARRIAGE SERVICES INC
# 4      63447  01    244         1   GES                     GUESS INC
# ...      ...  ..    ...       ...   ...                           ...
# 3400   22459  01      5         1    UE         URBAN EDGE PROPERTIES
# 3401   30293  01      5         1   ESS          ESSEX PROPERTY TRUST
# 3402   18468  01      5         1  PAGP         PLAINS GP HOLDINGS LP
# 3403  183324  01      5         1   PMT   PENNYMAC MORTGAGE INVEST TR
# 3404   45779  01      4         1   MRP       MILLROSE PROPERTIES INC
#
#       min_date  max_date
# 0     20050228  20250630
# 1     20050228  20250630
# 2     20050228  20250630
# 3     20050228  20250630
# 4     20050228  20250630
# ...        ...       ...
# 3400  20250228  20250630
# 3401  20250228  20250630
# 3402  20250228  20250630
# 3403  20250228  20250630
# 3404  20250331  20250630
#
# [3338 rows x 8 columns]

# %%
invst_univ_data.set_index(['gvkey','iid']).loc[(8901,'01')]
# Out:
# /tmp/ipykernel_258931/4138927408.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   invst_univ_data.set_index(['gvkey','iid']).loc[(8901,'01')]
#                        id      date  tic     conm  market_equity  \
# gvkey iid
# 8901  01       crsp_66683  20050228  NaN      NaN     741.926746
#       01       crsp_66683  20050331  NaN      NaN     750.844811
#       01       crsp_66683  20050429  NaN      NaN     660.248522
#       01       crsp_66683  20050531  NaN      NaN     632.097418
#       01       crsp_66683  20050630  NaN      NaN     639.998890
# ...                   ...       ...  ...      ...            ...
#       01   comp_008901_01  20250228  RES  RPC INC    1317.778360
#       01   comp_008901_01  20250331  NaN      NaN    1199.543760
#       01   comp_008901_01  20250430  NaN      NaN    1188.291500
#       01   comp_008901_01  20250530  NaN      NaN    1043.272450
#       01   comp_008901_01  20250630  NaN      NaN     979.308600
#
#             dolvol_126d  turnover_126d  ivol_ff3_21d   ni_ivol  beta_60m  ...  \
# gvkey iid                                                                 ...
# 8901  01   1.731443e+06       0.002787      0.014391  0.064323  0.796267  ...
#       01   2.112068e+06       0.003133      0.026980  0.064323  0.825528  ...
#       01   2.297776e+06       0.003322      0.026177  0.064323  0.782323  ...
#       01   2.414081e+06       0.003425      0.018815  0.060484  0.832617  ...
#       01   2.145315e+06       0.003072      0.020468  0.060484  0.841322  ...
# ...                 ...            ...           ...       ...       ...  ...
#       01   1.038197e+07       0.007673           NaN  0.169543       NaN  ...
#       01   1.017502e+07       0.007605           NaN  0.169543       NaN  ...
#       01   9.717867e+06       0.007459           NaN  0.169543       NaN  ...
#       01   9.347323e+06       0.007589           NaN  0.162604       NaN  ...
#       01   8.816181e+06       0.007343           NaN  0.162604       NaN  ...
#
#            rd_me     be_me  div12m_me     ni_me   sale_me  rf_feature  \
# gvkey iid
# 8901  01     NaN  0.248985   0.004646  0.036146  0.436523         NaN
#       01     NaN  0.246028   0.005742  0.035717  0.431338         NaN
#       01     NaN  0.279787   0.006529  0.040618  0.490524         NaN
#       01     NaN  0.305915   0.006820  0.055012  0.537563         NaN
#       01     NaN  0.302138   0.008102  0.054333  0.530926         NaN
# ...          ...       ...        ...       ...       ...         ...
#       01     NaN  0.855608   0.026098  0.090259  1.118677    0.028769
#       01     NaN  0.939942   0.028654  0.099155  1.228941         NaN
#       01     NaN  0.948843   0.028926  0.100094  1.240579         NaN
#       01     NaN  1.089342   0.032946  0.087651  1.356308         NaN
#       01     NaN  1.160492   0.035352  0.093376  1.444896         NaN
#
#            mgmt_feature  target_ret  year  month
# gvkey iid
# 8901  01            NaN    0.014347  2005      2
#       01            NaN   -0.127012  2005      3
#       01            NaN   -0.042791  2005      4
#       01            NaN    0.018569  2005      5
#       01            NaN    0.145565  2005      6
# ...                 ...         ...   ...    ...
#       01       0.003206   -0.083624  2025      2
#       01            NaN   -0.014337  2025      3
#       01            NaN   -0.140000  2025      4
#       01            NaN   -0.053439  2025      5
#       01            NaN    0.065315  2025      6
#
# [244 rows x 32 columns]

# %% [markdown]
# ## Collect Non US companies

# %%
# How many securirties have tpci information
(data[['gvkey','iid','fic','tpci']].drop_duplicates()
       .groupby('fic')
       .agg(lambda df: df.dropna()
                         .count()
                         
            )
).rename(columns={col: col+'_count' for col in ['gvkey','iid', 'tpci'] })

# %%
# No text data available for any of the foreign companies
data.loc[data[(data.fic !='USA')][['rf_feature', 'mgmt_feature']].dropna().index]
# Out:
#           gvkey  iid               id  tpci      date    tic  \
# 1187545   21216  01C  comp_021216_01C   0.0  20090331  GQM.H
# 1190207  157080  01C  comp_157080_01C   0.0  20090331   RVM.
# 1482424   21216  01C  comp_021216_01C   0.0  20100331  GQM.H
# 1777356   21216  01C  comp_021216_01C   0.0  20110331  GQM.H
#
#                                  conm  fic  market_equity    dolvol_126d  ...  \
# 1187545  GOLDEN QUEEN MINING CONS LTD  CAN      28.359696   25067.150240  ...
# 1190207          REVETT MINING CO INC  CAN       6.003634   28258.061869  ...
# 1482424  GOLDEN QUEEN MINING CONS LTD  CAN      81.859705   84248.930808  ...
# 1777356  GOLDEN QUEEN MINING CONS LTD  CAN     275.581230  152815.089600  ...
#
#          rd_me      be_me  div12m_me     ni_me   sale_me  rf_feature  \
# 1187545    NaN   0.148030        NaN -0.133239  0.000000    0.012001
# 1190207    NaN  10.169172        NaN -0.754830  6.000218    0.017320
# 1482424    NaN   0.038913        NaN -0.033315  0.000000    0.010856
# 1777356    NaN   0.028405        NaN -0.031024  0.000000    0.079420
#
#          mgmt_feature  target_ret  year  month
# 1187545      0.002423    0.104464  2009      3
# 1190207      0.004206   -0.047600  2009      3
# 1482424      0.002522    0.014359  2010      3
# 1777356      0.001790   -0.015715  2011      3
#
# [4 rows x 36 columns]

# %% [markdown]
# ### tpci seems not to be credible as a chatgpt search revealed where for canada, REVETT MINING CO INC has been acquired and whose ticker is defunct

# %%
data[(data.fic == 'CAN') & (~data.tpci.isna())].drop_duplicates()
# Out:
#           gvkey  iid               id  tpci      date    tic  \
# 1187545   21216  01C  comp_021216_01C   0.0  20090331  GQM.H
# 1190207  157080  01C  comp_157080_01C   0.0  20090331   RVM.
# 1482424   21216  01C  comp_021216_01C   0.0  20100331  GQM.H
# 1777356   21216  01C  comp_021216_01C   0.0  20110331  GQM.H
#
#                                  conm  fic  market_equity    dolvol_126d  ...  \
# 1187545  GOLDEN QUEEN MINING CONS LTD  CAN      28.359696   25067.150240  ...
# 1190207          REVETT MINING CO INC  CAN       6.003634   28258.061869  ...
# 1482424  GOLDEN QUEEN MINING CONS LTD  CAN      81.859705   84248.930808  ...
# 1777356  GOLDEN QUEEN MINING CONS LTD  CAN     275.581230  152815.089600  ...
#
#          rd_me      be_me  div12m_me     ni_me   sale_me  rf_feature  \
# 1187545    NaN   0.148030        NaN -0.133239  0.000000    0.012001
# 1190207    NaN  10.169172        NaN -0.754830  6.000218    0.017320
# 1482424    NaN   0.038913        NaN -0.033315  0.000000    0.010856
# 1777356    NaN   0.028405        NaN -0.031024  0.000000    0.079420
#
#          mgmt_feature  target_ret  year  month
# 1187545      0.002423    0.104464  2009      3
# 1190207      0.004206   -0.047600  2009      3
# 1482424      0.002522    0.014359  2010      3
# 1777356      0.001790   -0.015715  2011      3
#
# [4 rows x 36 columns]

# %% [markdown]
# # Anonymize Columns

# %%
# Select only numerical columns
numeric_cols = data.select_dtypes(include=[np.number]).columns.to_list()
for itm in ['date', 'target_ret', 'year', 'month']:
    numeric_cols.remove(itm)

# %%
char_list = ['market_equity', 'dolvol_126d',
       'turnover_126d', 'ivol_ff3_21d', 'ni_ivol', 'beta_60m', 'z_score',
       'f_score', 'netdebt_me', 'rd_sale', 'ebit_bev', 'ebit_sale', 'ni_be',
       'niq_be', 'ocf_at', 'gp_at', 'niq_at', 'op_at', 'rd_me', 'be_me',
       'div12m_me', 'ni_me', 'sale_me']

df1 = data[[col for col in data.columns if col not in numeric_cols]]
df1 = df1.drop(['year', 'month'], axis=1)

# %%
df2 = data[numeric_cols].div(data[numeric_cols].max(), axis=1
         ).mul(10000, axis=1
         ).rename(columns={'rf_feature':'txt_feat1', 'mgmt_feature':'txt_feat2'}
         ).rename(columns={col: f'quant_feat{i}' for i, col in enumerate(char_list)}
         )

# %%
pd.concat([df1,df2], axis=1).dropna().head(12)
# Out:
#            date   tic                   conm  fic  target_ret  quant_feat0  \
# 17590  20050228   XOM       EXXON MOBIL CORP  USA    0.232171   916.302044
# 17627  20050228    GR          GOODRICH CORP  USA    0.079592    11.228838
# 17707  20050228   TXN  TEXAS INSTRUMENTS INC  USA    0.140457   110.393120
# 17765  20050228    BA              BOEING CO  USA    0.091304   116.940078
# 17794  20050228   LMT   LOCKHEED MARTIN CORP  USA    0.028715    70.441883
# 17806  20050228   PFE             PFIZER INC  USA    0.096027   500.831094
# 18112  20050228  GNTX            GENTEX CORP  USA    0.002365     7.250993
# 18130  20050228   GGG              GRACO INC  USA    0.084432     6.783919
# 18132  20050228   B.2       BARNES GROUP INC  USA    0.047953     1.635118
# 18179  20050228   HNI               HNI CORP  USA    0.084882     6.239196
# 18188  20050228   ATI           ATI INC -NEW  USA    0.025417     6.309075
# 18256  20050228   BCR        BARD (C.R.) INC  USA   -0.019174    19.530391
#
#        quant_feat1  quant_feat2  quant_feat3   quant_feat4  ...  quant_feat15  \
# 17590  2669.904376     0.078678    76.294386  1.614773e-14  ...      0.028086
# 17627   102.114906     0.230355   170.575807  1.390029e-14  ...      0.022471
# 17707  1450.456629     0.320773   282.794459  4.782894e-14  ...      0.042106
# 17765   821.622024     0.160381   162.461613  1.750541e-14  ...      0.016243
# 17794   580.482524     0.196789   169.025984  1.456548e-14  ...      0.009884
# 17806  2768.950728     0.174684   139.066472  4.774918e-14  ...      0.034260
# 18112   158.518043     0.508051   289.751086  5.737711e-15  ...      0.026919
# 18130    43.814537     0.153732   217.462446  2.365028e-14  ...      0.090184
# 18132     8.822907     0.122346   128.767681  2.987445e-15  ...      0.038979
# 18179    22.513922     0.081571   181.676854  8.936659e-15  ...      0.074110
# 18188    94.566236     0.442700   455.355641  1.833781e-14  ...      0.009499
# 18256   167.637192     0.230389   202.804227  9.443383e-15  ...      0.051323
#
#        quant_feat16  quant_feat17  quant_feat18  quant_feat19  quant_feat20  \
# 17590      0.028587      0.030658      0.000253      0.012854      0.007557
# 17627      0.007659      0.014953      0.010428      0.011817      0.008460
# 17707      0.031952      0.050806      0.006600      0.012012      0.001454
# 17765      0.007350      0.015273      0.006118      0.008350      0.005491
# 17794      0.010657      0.014839      0.004817      0.010517      0.005774
# 17806      0.025043      0.032683      0.006548      0.016375      0.010327
# 18112      0.028102      0.035846      0.001549      0.010930      0.006864
# 18130      0.078435      0.078485      0.001142      0.003423      0.019462
# 18132      0.009820      0.014614      0.001149      0.021499      0.011329
# 18179      0.032832      0.035048      0.001553      0.011966      0.005175
# 18188      0.003805     -0.000494      0.000685      0.006330      0.003366
# 18256      0.050189      0.039276      0.002076      0.006679      0.002552
#
#        quant_feat21  quant_feat22  txt_feat1    txt_feat2
# 17590      0.011234      0.015670        0.0     8.550785
# 17627      0.005498      0.023800        0.0  2298.450883
# 17707      0.007457      0.006452        0.0     7.695706
# 17765      0.010316      0.026118        0.0  4074.876370
# 17794      0.007679      0.028634        0.0  2024.398239
# 17806      0.007915      0.006014        0.0     6.698115
# 18112      0.006815      0.004054        0.0   331.057875
# 18130      0.006599      0.004989        0.0   960.395616
# 18132      0.010010      0.034410        0.0  1225.042398
# 18179      0.007886      0.018748        0.0   767.432912
# 18188     -0.017168      0.022579        0.0  2541.578190
# 18256      0.005673      0.004824        0.0  1768.872294
#
# [12 rows x 30 columns]
