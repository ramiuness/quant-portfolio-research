# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Unifies the GHZ (2017) stock zoo used by both papers and tags usage for Goyenko & Zhang (2022) as “Both (alone & with options),”
# reflecting that they run stock-only and combined (stock+option)
pd.read_csv('../factor_zoo/combined_stock_characteristics.csv')

# %%
# Reconstructs the GHZ (2017) “factor zoo” as an expanded dictionary 
#(≈90 entries here; GHZ report 94). It follows the table labeling in the appendix
# of Goyenko & Zhang
pd.read_csv('factor_zoo/ghz_factor_zoo_full.csv')

# %%
# Full Option Zoo from Goyenko & Zhang (9 option characteristics + 15 risk-neutral moments) labeled Type=Option,
# then appends the GHZ stock zoo labeled Type=Stock
feature_zoo = pd.read_csv('../factor_zoo/option_zoo_plus_factor_zoo.csv')
option_zoo = (feature_zoo[feature_zoo['Type']=='Option'].drop(['Type', 'Reference'], axis=1)
        .rename(columns={'Characteristic': 'charcteristic', 'Group': 'category'}))  
option_zoo
# Out:
#           charcteristic                      category
# 0   avg_impl_volatility        ATM implied volatility
# 1                  cvol             Change in call IV
# 2                  pvol              Change in put IV
# 3                    cw            Call–Put IV spread
# 4                  hviv        Hist vol – Implied vol
# 5                med_hq     Borrowing fee (PC parity)
# 6          opt_baspread    Option bid-ask illiquidity
# 7                    os  Option-to-stock volume ratio
# 8              skewness               Volatility skew
# 9                 volq1              RN variance (1m)
# 10                volq2              RN variance (2m)
# 11                volq4              RN variance (4m)
# 12                volq5              RN variance (5m)
# 13                volq6              RN variance (6m)
# 14               skewq1              RN skewness (1m)
# 15               skewq2              RN skewness (2m)
# 16               skewq4              RN skewness (4m)
# 17               skewq5              RN skewness (5m)
# 18               skewq6              RN skewness (6m)
# 19               kurtq1              RN kurtosis (1m)
# 20               kurtq2              RN kurtosis (2m)
# 21               kurtq4              RN kurtosis (4m)
# 22               kurtq5              RN kurtosis (5m)
# 23               kurtq6              RN kurtosis (6m)

# %%
acc_ratios = pd.read_csv('../data/acc_ratios.csv')
acc_ratios
# Out:
#       Variable                       Description
# 0   netdebt_me                 Net debt-to-price
# 1      rd_sale                      R&D-to-sales
# 2     ebit_bev    Return on net operating assets
# 3    ebit_sale                     Profit margin
# 4        ni_be                  Return on equity
# 5       niq_be        Quarterly return on equity
# 6       ocf_at     Operating cash flow to assets
# 7        gp_at           Gross profits-to-assets
# 8       niq_at        Quarterly return on assets
# 9        op_at  Operating profits-to-book assets
# 10       rd_me                     R&D-to-market
# 11       be_me             Book-to-market equity
# 12   div12m_me                    Dividend yield
# 13       ni_me                 Earnings-to-price
# 14     sale_me                   Sales-to-market

# %%
stock_zoo =  ['be_me','market_equity','turnover_126d','gp_at','cop_at','inv_gr1','noa_at','ivol_capm_21d'] + ['size_log_me', 'bm','rev_1m','mom_7_12','inv_at','ivol','rvol','turnover','gp_at','op_at','ebit_sale','f_score','rd_me','inv_gr1','capx_gr1','capx_gr2','capx_gr3','noa_gr1a','ret_6_1','ret_9_1','ret_12_1','ret_12_7','market_equity','turnover_126d','bidaskhl_21d','zero_trades_126d']

lst_to_fetch = option_zoo['charcteristic'].to_list() + stock_zoo + acc_ratios['Variable'].to_list()

# %%
feature_glossary = pd.read_csv('../stock_char_appendix/table1.csv')
feature_glossary[feature_glossary['Acronym'].isin(lst_to_fetch)].sort_values('Acronym')
# Out:
#                                               Feature           Acronym  \
# 9                               Book-to-market equity             be_me
# 15                        The high-low bid-ask spread      bidaskhl_21d
# 18                             CAPEX growth (2 years)          capx_gr2
# 19                             CAPEX growth (3 years)          capx_gr3
# 24        Cash-based operating profits-to-book assets            cop_at
# 33                                     Dividend yield         div12m_me
# 40                     Return on net operating assets          ebit_bev
# 41                                      Profit margin         ebit_sale
# 49                                   Pitroski F-score           f_score
# 52                            Gross profits-to-assets             gp_at
# 55                                   Inventory growth           inv_gr1
# 60   Idiosyncratic volatility from the CAPM (21 days)     ivol_capm_21d
# 67                                      Market Equity     market_equity
# 72                                  Net debt-to-price        netdebt_me
# 76                                   Return on equity             ni_be
# 79                                  Earnings-to-price             ni_me
# 80                         Quarterly return on assets            niq_at
# 82                         Quarterly return on equity            niq_be
# 86                               Net operating assets            noa_at
# 91                      Operating cash flow to assets            ocf_at
# 95                                     Share turnover     turnover_126d
# 98  Number of zero trades with turnover as tiebrea...  zero_trades_126d
#
#                                        Reference
# 9             Rosenberg Reid and Lanstein (1985)
# 15                     Corwin and Schultz (2012)
# 18             Anderson and Garcia-Feijoo (2006)
# 19             Anderson and Garcia-Feijoo (2006)
# 24                                           NaN
# 33             Litzenberger and Ramaswamy (1979)
# 40                                Soliman (2008)
# 41                                Soliman (2008)
# 49                              Piotroski (2000)
# 52                              Novy-Marx (2013)
# 55                           Belo and Lin (2011)
# 60                                           NaN
# 67                                   Banz (1981)
# 72             Penman Richardson and Tuna (2007)
# 76                       Haugen and Baker (1996)
# 79                                   Basu (1983)
# 80         Balakrishnan Bartov and Faurel (2010)
# 82                      Hou Xue and Zhang (2015)
# 86                     Hirshleifer et al. (2004)
# 91  Bouchard, Krüger, Landier and Thesmar (2019)
# 95               Datar Naik and Radcliffe (1998)
# 98                                    Liu (2006)

# %%
ml_data = pd.read_csv('../data/ml_data.csv')

# %%
ml_data.tic.nunique()
# Out:
# 1568

# %%
import random
random.shuffle(lst_to_fetch)
dct = {'charc_to_fetch': lst_to_fetch,
       'tic' : ml_data['tic'].unique().tolist()
       }

# %%
dct
# Out:
# {'charc_to_fetch': ['capx_gr1',
#   'kurtq2',
#   'capx_gr2',
#   'capx_gr3',
#   'skewness',
#   'f_score',
#   'inv_gr1',
#   'skewq4',
#   'op_at',
#   'div12m_me',
#   'market_equity',
#   'ret_12_1',
#   'noa_at',
#   'kurtq4',
#   'cw',
#   'sale_me',
#   'gp_at',
#   'size_log_me',
#   'kurtq5',
#   'niq_be',
#   'ni_me',
#   'mom_7_12',
#   'cop_at',
#   'rev_1m',
#   'ret_6_1',
#   'volq6',
#   'turnover_126d',
#   'inv_gr1',
#   'ebit_sale',
#   'skewq6',
#   'skewq1',
#   'skewq5',
#   'ebit_bev',
#   'bidaskhl_21d',
#   'pvol',
#   'inv_at',
#   'volq4',
#   'avg_impl_volatility',
#   'opt_baspread',
#   'kurtq1',
#   'noa_gr1a',
#   'volq1',
#   'netdebt_me',
#   'rd_me',
#   'ni_be',
#   'ret_9_1',
#   'gp_at',
#   'ocf_at',
#   'be_me',
#   'turnover',
#   'ivol_capm_21d',
#   'rd_me',
#   'market_equity',
#   'be_me',
#   'volq5',
#   'skewq2',
#   'ebit_sale',
#   'kurtq6',
#   'turnover_126d',
#   'ret_12_7',
#   'med_hq',
#   'ivol',
#   'rvol',
#   'rd_sale',
#   'volq2',
#   'hviv',
#   'cvol',
#   'zero_trades_126d',
#   'gp_at',
#   'op_at',
#   'os',
#   'niq_at',
#   'bm'],
#  'tic': ['JJSF',
#   'PLXS',
#   'MSFT',
#   'RGEN',
#   'DLHC',
#   'BCPC',
#   'DJCO',
#   'ASTE',
#   'WERN',
#   'AMWD',
#   'ADM',
#   'PAMT',
#   'FI',
#   'HTLD',
#   'CAL',
#   'BC',
#   'UIS',
#   'AVD',
#   'CRMT',
#   'CFNB',
#   'CATO',
#   'KO',
#   'DXLG',
#   'CDNS',
#   'CECO',
#   'FICO',
#   'CNMD',
#   'EPAC',
#   'XRAY',
#   'FAST',
#   'DTE',
#   'MATX',
#   'IMKTA',
#   'AIN',
#   'ETN',
#   'JOUT',
#   'XOM',
#   'IPAR',
#   'MGM',
#   'WM',
#   'COKE',
#   'DY',
#   'GATX',
#   'GD',
#   'GE',
#   'LH',
#   'LWAY',
#   'LNN',
#   'MGPI',
#   'TT',
#   'IBM',
#   'ITT',
#   'SR',
#   'OLN',
#   'PCG',
#   'PEP',
#   'MO',
#   'COP',
#   'PVH',
#   'AMGN',
#   'SLB',
#   'APOG',
#   'CVX',
#   'AMAT',
#   'TKR',
#   'TR',
#   'VMC',
#   'FL',
#   'TXN',
#   'EIX',
#   'HSY',
#   'CVS',
#   'BSET',
#   'GIS',
#   'SPGI',
#   'CCK',
#   'WRB',
#   'KMB',
#   'RTX',
#   'UGI',
#   'CW',
#   'PG',
#   'SO',
#   'CAT',
#   'BCO',
#   'CL',
#   'BRC',
#   'FMC',
#   'DE',
#   'BMY',
#   'BA',
#   'MTZ',
#   'CR',
#   'JEF',
#   'ABT',
#   'CACI',
#   'CALM',
#   'CRS',
#   'DD',
#   'CWT',
#   'GCO',
#   'LMT',
#   'NEM',
#   'IP',
#   'EXC',
#   'CNP',
#   'IDA',
#   'PFE',
#   'JNJ',
#   'GLW',
#   'PPG',
#   'PPL',
#   'MMM',
#   'MRK',
#   'MSI',
#   'FE',
#   'CPK',
#   'CMS',
#   'EAT',
#   'CHD',
#   'WEC',
#   'TXT',
#   'CTAS',
#   'PEG',
#   'CIA',
#   'HAL',
#   'MDU',
#   'XEL',
#   'ETR',
#   'EVRG',
#   'AEP',
#   'NEE',
#   'ALE',
#   'ASH',
#   'EQT',
#   'OGE',
#   'CDE',
#   'NOC',
#   'AEE',
#   'NVRI',
#   'WHR',
#   'CAR',
#   'LHX',
#   'NFG',
#   'F',
#   'DOV',
#   'BH',
#   'CTO',
#   'L',
#   'K',
#   'CSL',
#   'CLF',
#   'CBRL',
#   'R',
#   'AVT',
#   'HPQ',
#   'BAX',
#   'DUK',
#   'XRX',
#   'PNW',
#   'NC',
#   'APD',
#   'MUR',
#   'CTS',
#   'ALK',
#   'NBR',
#   'ARW',
#   'COHU',
#   'CMC',
#   'FLS',
#   'HL',
#   'HEI',
#   'HP',
#   'HRL',
#   'HUBB',
#   'IMO',
#   'ENZN',
#   'ESCA',
#   'BOOM',
#   'MAS',
#   'NPKI',
#   'NUE',
#   'OXY',
#   'OXM',
#   'ROG',
#   'ROL',
#   'SEB',
#   'SHW',
#   'FLXS',
#   'SCL',
#   'FSTR',
#   'FELE',
#   'BEN',
#   'FUL',
#   'AJG',
#   'WMB',
#   'GNTX',
#   'NI',
#   'SMP',
#   'APA',
#   'MAT',
#   'GGG',
#   'BDX',
#   'IFF',
#   'TJX',
#   'CMI',
#   'HVT',
#   'PH',
#   'HELE',
#   'RVTY',
#   'WWW',
#   'HNI',
#   'JCI',
#   'NEU',
#   'SJM',
#   'JBHT',
#   'ATI',
#   'SWK',
#   'MCD',
#   'SXI',
#   'VFC',
#   'ES',
#   'TFX',
#   'AVY',
#   'ADP',
#   'TILE',
#   'DIOD',
#   'MMC',
#   'SWKS',
#   'SFES',
#   'GFF',
#   'CLX',
#   'GPC',
#   'CBT',
#   'KLAC',
#   'PNRG',
#   'NYT',
#   'EBF',
#   'CNA',
#   'FSS',
#   'TGNA',
#   'KLIC',
#   'LZB',
#   'LRCX',
#   'MCO',
#   'MZTI',
#   'HUM',
#   'DSGR',
#   'TGT',
#   'HRB',
#   'DDS',
#   'RRC',
#   'TPC',
#   'LLY',
#   'SMTC',
#   'MTW',
#   'TER',
#   'MCS',
#   'SCI',
#   'MLP',
#   'SYY',
#   'MKC',
#   'RHI',
#   'J',
#   'SSUP',
#   'EFX',
#   'GWW',
#   'LEN',
#   'WTRG',
#   'MCY',
#   'HAS',
#   'IPG',
#   'BMI',
#   'MEI',
#   'GHC',
#   'GRC',
#   'MU',
#   'MSEX',
#   'MLKN',
#   'HTO',
#   'MSA',
#   'AIR',
#   'MOD',
#   'SPXC',
#   'TXNM',
#   'MTRN',
#   'WMT',
#   'LPX',
#   'CAG',
#   'ITW',
#   'TRC',
#   'BALL',
#   'VSH',
#   'NDSN',
#   'AFL',
#   'TEX',
#   'NWN',
#   'LUV',
#   'RRX',
#   'LNT',
#   'GAP',
#   'KEX',
#   'AXP',
#   'TAP',
#   'INTC',
#   'TRV',
#   'TWIN',
#   'ACU',
#   'MDT',
#   'OTTR',
#   'OMI',
#   'SNA',
#   'GHM',
#   'PCAR',
#   'TTC',
#   'LUMN',
#   'AFG',
#   'ADI',
#   'LEG',
#   'NWL',
#   'SWX',
#   'AMD',
#   'PKOH',
#   'LOW',
#   'BIO',
#   'PAYX',
#   'AON',
#   'BKH',
#   'PNR',
#   'TMO',
#   'GL',
#   'WST',
#   'AGYS',
#   'DCO',
#   'BRO',
#   'POWL',
#   'TDS',
#   'CI',
#   'CHE',
#   'BBWI',
#   'NSC',
#   'PGR',
#   'NJR',
#   'KWR',
#   'D',
#   'RLI',
#   'UNF',
#   'MYE',
#   'AOS',
#   'COO',
#   'USLM',
#   'VZ',
#   'T',
#   'NAVI',
#   'WSO',
#   'WDC',
#   'RES',
#   'AIG',
#   'UTL',
#   'BIGGQ',
#   'RGLD',
#   'SEIC',
#   'WTM',
#   'REX',
#   'MS',
#   'VTRS',
#   'STZ',
#   'HOG',
#   'KBH',
#   'ECL',
#   'PPC',
#   'UNM',
#   'SON',
#   'STAA',
#   'NHC',
#   'STC',
#   'SF',
#   'SYK',
#   'RGR',
#   'PII',
#   'MAN',
#   'AD',
#   'MTH',
#   'TNC',
#   'MIDD',
#   'ADBE',
#   'MRTN',
#   'ODP',
#   'IEX',
#   'CRUS',
#   'GEN',
#   'TG',
#   'CGNX',
#   'TECH',
#   'EOG',
#   'DGII',
#   'GIII',
#   'NEOG',
#   'THO',
#   'CTRA',
#   'HOLX',
#   'JOE',
#   'TTI',
#   'VICR',
#   'GVA',
#   'KMPR',
#   'TYL',
#   'BHE',
#   'EXPO',
#   'AN',
#   'MMSI',
#   'ESE',
#   'MLI',
#   'DORM',
#   'REGN',
#   'IONS',
#   'IDXX',
#   'RGS',
#   'AES',
#   'CRVL',
#   'DIN',
#   'ALKS',
#   'MNRO',
#   'PRGS',
#   'ZBRA',
#   'EZPW',
#   'HAE',
#   'FIZZ',
#   'BIIB',
#   'AAON',
#   'TRNS',
#   'ODFL',
#   'ATNI',
#   'WRLD',
#   'WNC',
#   'HMN',
#   'OI',
#   'AMSC',
#   'QCOM',
#   'PRGO',
#   'TTEK',
#   'GILD',
#   'SCHL',
#   'MODG',
#   'ICUI',
#   'JACK',
#   'M',
#   'MHK',
#   'KOPN',
#   'AGCO',
#   'BKE',
#   'ARCB',
#   'BSX',
#   'KSS',
#   'OLED',
#   'USPH',
#   'STE',
#   'CACC',
#   'DHI',
#   'SBUX',
#   'TSN',
#   'LIN',
#   'CAKE',
#   'ASGN',
#   'LFUS',
#   'MTX',
#   'RDN',
#   'UFI',
#   'KAI',
#   'LGND',
#   'SM',
#   'OPY',
#   'DDD',
#   'OFIX',
#   'MTCH',
#   'WOLF',
#   'AORT',
#   'ALG',
#   'INTU',
#   'LSTR',
#   'MCHP',
#   'SCVL',
#   'CHDN',
#   'ETD',
#   'FOSL',
#   'JBL',
#   'ORLY',
#   'SANM',
#   'ATR',
#   'RCL',
#   'ANIK',
#   'TWI',
#   'RGA',
#   'RIG',
#   'BBSI',
#   'PZZA',
#   'ALL',
#   'MCRI',
#   'BWA',
#   'MOV',
#   'UHS',
#   'DECK',
#   'BYD',
#   'NVR',
#   'NSTM',
#   'FWRD',
#   'PTEN',
#   'ROCK',
#   'UFPI',
#   'VIAV',
#   'URBN',
#   'HHS',
#   'INCY',
#   'MHO',
#   'SHOO',
#   'UFPT',
#   'EMN',
#   'VMI',
#   'HAIN',
#   'AGM',
#   'ALB',
#   'BZH',
#   'MLM',
#   'DAKT',
#   'TSCO',
#   'BHC',
#   'CPRT',
#   'FLEX',
#   'SCSC',
#   'ZEUS',
#   'EXP',
#   'AEO',
#   'NKTR',
#   'PENN',
#   'SSD',
#   'GBX',
#   'MATW',
#   'GEO',
#   'ADTN',
#   'RS',
#   'SIRI',
#   'DAR',
#   'CVLG',
#   'KNX',
#   'COF',
#   'MCK',
#   'VECO',
#   'NSIT',
#   'AZTA',
#   'STRT',
#   'ACIW',
#   'COR',
#   'CBZ',
#   'CWCO',
#   'HLIT',
#   'DRI',
#   'GIC',
#   'WAB',
#   'LECO',
#   'RMD',
#   'SBGI',
#   'FCX',
#   'IART',
#   'KFRC',
#   'NOVT',
#   'MD',
#   'ACGL',
#   'SMSI',
#   'EG',
#   'DVA',
#   'ERIE',
#   'MYGN',
#   'POOL',
#   'RICK',
#   'AEIS',
#   'HSIC',
#   'NTAP',
#   'NWPX',
#   'SAM',
#   'EL',
#   'MATV',
#   'WAT',
#   'EME',
#   'HIG',
#   'MSM',
#   'SCCO',
#   'OTEX',
#   'WSM',
#   'ANDE',
#   'CMCO',
#   'CSGS',
#   'IRM',
#   'GEF',
#   'CENX',
#   'HUBG',
#   'KVHI',
#   'FCN',
#   'JAKK',
#   'NBIX',
#   'FDS',
#   'WOR',
#   'TBI',
#   'RNR',
#   'GERN',
#   'PEGA',
#   'STRA',
#   'GES',
#   'CSV',
#   'LAMR',
#   'MVIS',
#   'TTEC',
#   'ANF',
#   'USNA',
#   'NOV',
#   'PAG',
#   'BJRI',
#   'NUS',
#   'SSP',
#   'STLD',
#   'UNFI',
#   'LAD',
#   'VSAT',
#   'VYX',
#   'DGX',
#   'ROK',
#   'NSP',
#   'WWD',
#   'HLIO',
#   'VCEL',
#   'CIEN',
#   'SLGN',
#   'EEFT',
#   'ALV',
#   'LNG',
#   'GIFI',
#   'TTWO',
#   'APH',
#   'SRPT',
#   'QRVO',
#   'FIX',
#   'HLX',
#   'DXPE',
#   'AROC',
#   'JLL',
#   'AME',
#   'VLO',
#   'YUM',
#   'PLCE',
#   'PSMT',
#   'SIGA',
#   'SNDA',
#   'INVX',
#   'RHP',
#   'GPI',
#   'SRI',
#   'FDP',
#   'CHRW',
#   'CWST',
#   'OSIS',
#   'AMG',
#   'MTD',
#   'ADSK',
#   'INGR',
#   'URI',
#   'POWI',
#   'PRDO',
#   'RMTI',
#   'WPC',
#   'IESC',
#   'PWR',
#   'SCS',
#   'COLM',
#   'CNXN',
#   'SRDX',
#   'MAR',
#   'BBY',
#   'SEE',
#   'CRAI',
#   'MANH',
#   'IOSP',
#   'AMKR',
#   'HCKT',
#   'WCN',
#   'FHI',
#   'AMT',
#   'HZO',
#   'SRE',
#   'CTSH',
#   'MSTR',
#   'RSG',
#   'BELFB',
#   'CSGP',
#   'CCI',
#   'EBAY',
#   'SNBR',
#   'AXL',
#   'NVDA',
#   'KFY',
#   'MTEX',
#   'BB',
#   'MKSI',
#   'CNX',
#   'TREX',
#   'EXTR',
#   'HSII',
#   'GS',
#   'WCC',
#   'SKX',
#   'UTHR',
#   'LII',
#   'QMCO',
#   'BMRN',
#   'ZD',
#   'SALM',
#   'DVN',
#   'NTCT',
#   'GAIA',
#   'ONTO',
#   'LCII',
#   'KTOS',
#   'A',
#   'TDY',
#   'UPS',
#   'RDI',
#   'PKG',
#   'AGEN',
#   'EW',
#   'EPC',
#   'EXPD',
#   'SLAB',
#   'MNST',
#   'EXEL',
#   'HSTM',
#   'LXRX',
#   'LPSN',
#   'SGMO',
#   'OSPN',
#   'PXLW',
#   'CRL',
#   'CYH',
#   'ISRG',
#   'MRVL',
#   'UONEK',
#   'ENTG',
#   'EVC',
#   'CRIS',
#   'SPTN',
#   'AVNT',
#   'ITGR',
#   'DRRX',
#   'TTMI',
#   'TPR',
#   'SHEN',
#   'INSG',
#   'ALGN',
#   'GPN',
#   'MPX',
#   'FLO',
#   'CP',
#   'OVV',
#   'PLPC',
#   'TCI',
#   'LYTS',
#   'MGRC',
#   'OSK',
#   'ROST',
#   'OSUR',
#   'CLH',
#   'GT',
#   'SPB',
#   'ALNT',
#   'SLNH',
#   'TRN',
#   'OII',
#   'SXT',
#   'WKC',
#   'LSCC',
#   'QDEL',
#   'FCFS',
#   'CB',
#   'BCRX',
#   'SENEA',
#   'SAH',
#   'BGC',
#   'ILMN',
#   'BRKR',
#   'GRMN',
#   'OIS',
#   'BFH',
#   'MDLZ',
#   'AXON',
#   'ZBH',
#   'OMCL',
#   'ELV',
#   'AMN',
#   'AAP',
#   'KR',
#   'DBI',
#   'HWKN',
#   'VRSN',
#   'RUSHA',
#   'SYNA',
#   'KMX',
#   'CMCSA',
#   'MED',
#   'AYI',
#   'EQIX',
#   'VRTX',
#   'AKAM',
#   'FIS',
#   'SNPS',
#   'HOFT',
#   'WTS',
#   'OKE',
#   'IDCC',
#   'DHIL',
#   'WTW',
#   'CCRN',
#   'CCOI',
#   'ABG',
#   'JBLU',
#   'NFLX',
#   'BGFV',
#   'WHG',
#   'RRGB',
#   'SAIA',
#   'WYNN',
#   'PRAA',
#   'SAFT',
#   'DKS',
#   'AAPL',
#   'HXL',
#   'MERC',
#   'AMZN',
#   'RBBN',
#   'PRU',
#   'LIVN',
#   'ECPG',
#   'GPK',
#   'WEN',
#   'CNO',
#   'STX',
#   'TZOO',
#   'CERS',
#   'NG',
#   'CVGW',
#   'NRG',
#   'STRL',
#   'LNW',
#   'FLR',
#   'NGS',
#   'NTGR',
#   'LKQ',
#   'CRI',
#   'NNI',
#   'PIPR',
#   'SGI',
#   'AIZ',
#   'TBHC',
#   'NPO',
#   'CVCO',
#   'PETS',
#   'SWBI',
#   'IIIN',
#   'ANGO',
#   'NWE',
#   'SPOK',
#   'HLF',
#   'DLX',
#   'CME',
#   'UTI',
#   'HOV',
#   'NDAQ',
#   'MKL',
#   'THC',
#   'IMMR',
#   'AXS',
#   'MCHX',
#   'UCTT',
#   'CBRE',
#   'BLKB',
#   'MNKD',
#   'WLK',
#   'GOOGL',
#   'HURN',
#   'TXRH',
#   'NP',
#   'ORA',
#   'MPWR',
#   'CHCI',
#   'BXC',
#   'LVS',
#   'WTI',
#   'HUN',
#   'CRM',
#   'CASS',
#   'ON',
#   'MOH',
#   'CMP',
#   'ENS',
#   'EXPE',
#   'MOS',
#   'AGO',
#   'DLB',
#   'DINO',
#   'LNC',
#   'ROP',
#   'RMBS',
#   'CAAS',
#   'MKTX',
#   'CE',
#   'WEX',
#   'RAIL',
#   'LAZ',
#   'MORN',
#   'WBD',
#   'ACCO',
#   'CF',
#   'OFLX',
#   'FNF',
#   'AMSF',
#   'IRBT',
#   'JSDA',
#   'UAA',
#   'CCO',
#   'ICE',
#   'LYV',
#   'CMG',
#   'CROX',
#   'POR',
#   'DLTR',
#   'CTRN',
#   'PRSU',
#   'PBH',
#   'RBC',
#   'KOP',
#   'GTLS',
#   'KALU',
#   'LFCR',
#   'CVLT',
#   'IT',
#   'CMPR',
#   'MA',
#   'OC',
#   'GLDD',
#   'PHM',
#   'WWR',
#   'IMAX',
#   'OMEX',
#   'GNW',
#   'BLDR',
#   'AMP',
#   'BKD',
#   'ATEC',
#   'SNCR',
#   'EVR',
#   'WU',
#   'ICFI',
#   'EXLS',
#   'AWI',
#   'EBS',
#   'NLST',
#   'IPGP',
#   'EIG',
#   'DAL',
#   'BGS',
#   'TRS',
#   'OPK',
#   'EHTH',
#   'AVAV',
#   'DXCM',
#   'ARAY',
#   'SMCI',
#   'IVZ',
#   'GENC',
#   'UFCS',
#   'DAN',
#   'CLDX',
#   'UVE',
#   'SSRM',
#   'TNL',
#   'AYR',
#   'FSLR',
#   'ALGT',
#   'CNK',
#   'CLNE',
#   'IBKR',
#   'PODD',
#   'PRO',
#   'MASI',
#   'MELI',
#   'G',
#   'TDC',
#   'ORN',
#   'FOR',
#   'AWK',
#   'GTE',
#   'LDOS',
#   'LULU',
#   'ULTA',
#   ...]}

# %%
import json

# Assuming dct is your dictionary
with open('../data/fetch_frm_wrds.json', 'w') as f:
    json.dump(dct, f)

# %%
with open('../data/fetch_frm_wrds.json', 'r') as f:
    dct_loaded = json.load(f)

# %%
dct_loaded.keys()
# Out:
# dict_keys(['charc_to_fetch', 'tic'])

# %%
# 25 stock variables drawn from Gu, Kelly & Xiu (2020) and Green, Hand & Zhang (2017)
stock_char_short = pd.read_csv('../factor_zoo/stock_characteristics.csv')
stock_char_short
# Out:
#    Characteristic                                          Reference  \
# 0           mom1m  Gu, Kelly & Xiu (2020); Green, Hand & Zhang (2...
# 1           mom6m                         Green, Hand & Zhang (2017)
# 2          mom12m  Gu, Kelly & Xiu (2020); Green, Hand & Zhang (2...
# 3          mom36m                             Gu, Kelly & Xiu (2020)
# 4           chmom                             Gu, Kelly & Xiu (2020)
# 5          indmom                             Gu, Kelly & Xiu (2020)
# 6          maxret                             Gu, Kelly & Xiu (2020)
# 7            turn  Gu, Kelly & Xiu (2020); Green, Hand & Zhang (2...
# 8        std_turn                             Gu, Kelly & Xiu (2020)
# 9           mvel1                             Gu, Kelly & Xiu (2020)
# 10         dolvol                             Gu, Kelly & Xiu (2020)
# 11            ill                             Gu, Kelly & Xiu (2020)
# 12      zerotrade                         Green, Hand & Zhang (2017)
# 13       baspread                             Gu, Kelly & Xiu (2020)
# 14         retvol                             Gu, Kelly & Xiu (2020)
# 15        idiovol                             Gu, Kelly & Xiu (2020)
# 16           beta                             Gu, Kelly & Xiu (2020)
# 17         betasq                             Gu, Kelly & Xiu (2020)
# 18             ep  Gu, Kelly & Xiu (2020); Green, Hand & Zhang (2...
# 19             sp  Gu, Kelly & Xiu (2020); Green, Hand & Zhang (2...
# 20            agr  Gu, Kelly & Xiu (2020); Green, Hand & Zhang (2...
# 21          nincr                             Gu, Kelly & Xiu (2020)
# 22             bm                         Green, Hand & Zhang (2017)
# 23           cash                         Green, Hand & Zhang (2017)
# 24           prof                         Green, Hand & Zhang (2017)
# 25         zscore                         Green, Hand & Zhang (2017)
#
#                                  Group
# 0             Price trends / reversals
# 1                         Price trends
# 2                         Price trends
# 3    Price trends (long-term reversal)
# 4                         Price trends
# 5                    Industry momentum
# 6   Price trends / extreme past return
# 7                 Liquidity / turnover
# 8      Liquidity / turnover volatility
# 9                     Size / liquidity
# 10               Dollar trading volume
# 11                  Amihud illiquidity
# 12       Liquidity / zero-trading days
# 13          Bid-ask spread illiquidity
# 14      Risk / total return volatility
# 15     Risk / idiosyncratic volatility
# 16                  Risk / market beta
# 17                 Risk / squared beta
# 18               Valuation ratio (E/P)
# 19       Valuation ratio (Sales/Price)
# 20                        Asset growth
# 21        Number of earnings increases
# 22                      Book-to-market
# 23                         Cash/Assets
# 24              Profitability measures
# 25                      Altman Z-score

# %%
factor_glossary = pd.read_csv('./table1/table1.csv')
factor_features = pd.read_csv('./data/factor_char_list.csv').values.flatten().tolist()

# Distinguish referenced and non referenced factors
factors_no_ref = list(set(factor_features)-set(factor_glossary["Acronym"].values))
factors_with_ref = list(set(factor_features).intersection(set(factor_glossary["Acronym"].values)))

# List refrenced factors
idx_factor_features = factor_glossary.index[factor_glossary["Acronym"].isin(factors_with_ref)].tolist()
factor_glossary.iloc[idx_factor_features].reset_index().drop('index', axis=1).rename(columns={'Feature':'Referenced Factors'})

# %%
# Check if all factor features are in acc_ratios
acc_ratios = pd.read_csv('./data/acc_ratios.csv')
set(factor_features).intersection(set(acc_ratios.Variable)) == set(acc_ratios.Variable)
# Out:
# True

# %%
# Load the short list of features used in modeling
features_short = pd.read_csv('data/referenced_predictive_factors.csv')
features_short
# Out:
#   Predictive_Var                                   Feature        Acronym  \
# 0  market_equity                             Market Equity  market_equity
# 1    dolvol_126d                     Dollar trading volume    dolvol_126d
# 2  turnover_126d                            Share turnover  turnover_126d
# 3       rvol_21d  Idiosyncratic volatility (FF3 residuals)   ivol_ff3_21d
# 4        ni_ivol                       Earnings volatility        ni_ivol
# 5       beta_60m                               Market Beta       beta_60m
# 6        z_score                            Altman Z-score        z_score
# 7        f_score                         Piotroski F-score        f_score
#
#                                 Reference              Category  \
# 0                             Banz (1981)                  Size
# 1  Brennan, Chordia & Subrahmanyam (1998)             Liquidity
# 2          Datar, Naik & Radcliffe (1998)              Turnover
# 3                       Ang et al. (2006)            Volatility
# 4                   Francis et al. (2004)            Volatility
# 5                   Fama & MacBeth (1973)                  Beta
# 6                           Dichev (1998)              Distress
# 7                        Piotroski (2000)  Fundamentals Quality
#
#    Empirical_Rank
# 0               3
# 1               1
# 2               2
# 3               4
# 4               5
# 5               6
# 6               7
# 7               8

# %%
l = features_short['Acronym'].tolist()
l.extend(acc_ratios.Variable.tolist())

# %%
import polars as p
df = pl.scan_csv('MAIN DATA and SUPPORTING CODES/ret_sample.csv').select(l).collect().to_pandas()

# %%
df.shape
# Out:
# (6401414, 23)
